# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# ### Working with Dates

# %%
# Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
date['date_year'] = date['date'].dt.year

date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year
# 935 2019-10-30        1931        0      57       2019
# 300 2019-05-31        2981       26    1004       2019
# 455 2018-09-08        5330       26       6       2018
# 59  2019-10-25        4756        2      13       2019
# 753 2018-11-30        5618       21      13       2018

# %%
date['date_month_no'] = date['date'].dt.month

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1

# %%
date['date_month_name'] = date['date'].dt.month_name()

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name
# 0        December
# 1          August
# 2         October
# 3          August
# 4         January

# %%
date['date_day'] = date['date'].dt.day

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_day
# 0        December        10
# 1          August        15
# 2         October        23
# 3          August        17
# 4         January         6

# %%
# day of week
date['date_dow'] = date['date'].dt.dayofweek

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_day  date_dow
# 0        December        10         1
# 1          August        15         2
# 2         October        23         1
# 3          August        17         5
# 4         January         6         6

# %%
# day of week - name

date['date_dow_name'] = date['date'].dt.day_name()

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name
# 0       Tuesday
# 1     Wednesday
# 2       Tuesday
# 3      Saturday
# 4        Sunday

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name  date_is_weekend
# 0       Tuesday                0
# 1     Wednesday                0
# 2       Tuesday                0
# 3      Saturday                1
# 4        Sunday                1

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#                        date  date_year  date_month_no date_month_name  \
# 0 2019-12-09 19:00:00-05:00       2019             12        December
# 1 2018-08-14 20:00:00-04:00       2018              8          August
# 2 2018-10-22 20:00:00-04:00       2018             10         October
# 3 2019-08-16 20:00:00-04:00       2019              8          August
# 4 2019-01-05 19:00:00-05:00       2019              1         January
#
#    date_day  date_dow date_dow_name  date_is_weekend  quarter
# 0        10         1       Tuesday                0        4
# 1        15         2     Wednesday                0        3
# 2        23         1       Tuesday                0        4
# 3        17         5      Saturday                1        3
# 4         6         6        Sunday                1        1

# %%
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#                        date  date_year  date_month_no date_month_name  \
# 0 2019-12-09 19:00:00-05:00       2019             12        December
# 1 2018-08-14 20:00:00-04:00       2018              8          August
# 2 2018-10-22 20:00:00-04:00       2018             10         October
# 3 2019-08-16 20:00:00-04:00       2019              8          August
# 4 2019-01-05 19:00:00-05:00       2019              1         January
#
#    date_day  date_dow date_dow_name  date_is_weekend  quarter  semester
# 0        10         1       Tuesday                0        4         2
# 1        15         2     Wednesday                0        3         2
# 2        23         1       Tuesday                0        4         2
# 3        17         5      Saturday                1        3         2
# 4         6         6        Sunday                1        1         1

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2026, 3, 31, 22, 36, 9, 122848)

# %%
today = pd.Timestamp.today().tz_localize(None)

months_passed = np.round((today - date['date']) / np.timedelta64(1, 'M'), 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1188, in DatetimeLikeArrayMixin._sub_datetimelike(self, other)
#    1187 try:
# -> 1188     self._assert_tzawareness_compat(other)
#    1189 except TypeError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:788, in DatetimeArray._assert_tzawareness_compat(self, other)
#     787 elif other_tz is None:
# --> 788     raise TypeError(
#     789         "Cannot compare tz-naive and tz-aware datetime-like objects"
#     790     )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 today = pd.Timestamp.today().tz_localize(None)
# ----> 3 months_passed = np.round((today - date['date']) / np.timedelta64(1, 'M'), 0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6154, in Series._arith_method(self, other, op)
#    6152 def _arith_method(self, other, op):
#    6153     self, other = self._align_for_op(other)
# -> 6154     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:1391, in IndexOpsMixin._arith_method(self, other, op)
#    1388     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1390 with np.errstate(all="ignore"):
# -> 1391     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1393 return self._construct_result(result, name=res_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:273, in arithmetic_op(left, right, op)
#     260 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     261 #  have already been called on `left` and `right`,
#     262 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     263 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     264 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     266 if (
#     267     should_extension_dispatch(left, right)
#     268     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    271     # Timedelta/Timestamp and other custom scalars are included in the check
#     272     # because numexpr will fail on it, see GH#31457
# --> 273     res_values = op(left, right)
#     274 else:
#     275     # TODO we should handle EAs consistently and move this check before the if/else
#     276     # (https://github.com/pandas-dev/pandas/issues/41165)
#     277     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     278     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1533, in DatetimeLikeArrayMixin.__rsub__(self, other)
#    1530     return (-self) + other
#    1532 # We get here with e.g. datetime objects
# -> 1533 return -(self - other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1459, in DatetimeLikeArrayMixin.__sub__(self, other)
#    1457     result = self._add_offset(-other)
#    1458 elif isinstance(other, (datetime, np.datetime64)):
# -> 1459     result = self._sub_datetimelike_scalar(other)
#    1460 elif lib.is_integer(other):
#    1461     # This check must come after the check for np.timedelta64
#    1462     # as is_integer returns True for these
#    1463     if not isinstance(self.dtype, PeriodDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1166, in DatetimeLikeArrayMixin._sub_datetimelike_scalar(self, other)
#    1163 ts = Timestamp(other)
#    1165 self, ts = self._ensure_matching_resos(ts)
# -> 1166 return self._sub_datetimelike(ts)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1191, in DatetimeLikeArrayMixin._sub_datetimelike(self, other)
#    1189 except TypeError as err:
#    1190     new_message = str(err).replace("compare", "subtract")
# -> 1191     raise type(err)(new_message) from err
#    1193 other_i8, o_mask = self._get_i8_values_and_mask(other)
#    1194 res_values = add_overflowsafe(self.asi8, np.asarray(-other_i8, dtype="i8"))
#
# TypeError: Cannot subtract tz-naive and tz-aware datetime-like objects
