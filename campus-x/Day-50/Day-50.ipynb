# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px 
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0  0.130484  2.432814  11.417628
# 1 -0.942608 -1.582275 -47.896260
# 2  0.650128 -0.266438  90.880056
# 3  0.951000 -0.818716  29.593841
# 4  0.369459  0.024061  16.043368

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 46.228789977076026
# MSE 2610.663874479952
# R2 score 0.0849706694096719

# %%
# Import necessary libraries (assuming they're needed)
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
# Assuming lr (linear regression model) is already defined
# Assuming df is already defined

# Create the grid
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

# Define final BEFORE using it
final = np.vstack((xGrid.ravel().reshape(1,100), yGrid.ravel().reshape(1,100))).T

# Now use final to make predictions
z_final = lr.predict(final).reshape(10,10)
z = z_final

# Create the 3D plot
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.add_trace(go.Surface(x=x, y=y, z=z))
fig.show()

# %%
lr.coef_
# Out:
# array([16.45375348, -6.95617403])

# %%
lr.intercept_
# Out:
# np.float64(9.695545682188484)
