# %%
import pandas as pd

# %%
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     32.8997
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     34.6298
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     17.1064
# 3  The true story of how businessman Oskar Schind...   1993-12-15     14.7781
# 4  The defense and the prosecution have rested an...   1957-04-10     14.8697
#
#    vote_average  vote_count
# 0         8.715       29827
# 1         8.700       22523
# 2         8.571       13632
# 3         8.566       17154
# 4         8.556        9776

# %%
temp_df = pd.DataFrame()

# %%
df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6      155                                The Dark Knight
# 7    19404                    Dilwale Dulhania Le Jayenge
# 8      497                                 The Green Mile
# 9      122  The Lord of the Rings: The Return of the King
# 10  496243                                       Parasite
# 11     680                                   Pulp Fiction
# 12  372058                                     Your Name.
# 13  157336                                   Interstellar
# 14     429                 The Good, the Bad and the Ugly
# 15      13                                   Forrest Gump
# 16     769                                     GoodFellas
# 17     346                                  Seven Samurai
# 18   12477                         Grave of the Fireflies
# 19     637                              Life Is Beautiful
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   The defense and the prosecution have rested an...   1957-04-10
# 5   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 6   Batman raises the stakes in his war on crime. ...   2008-07-16
# 7   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 8   A supernatural tale set on death row in a Sout...   1999-12-10
# 9   As armies mass for a final battle that will de...   2003-12-17
# 10  All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 11  A burger-loving hit man, his philosophical par...   1994-09-10
# 12  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 13  The adventures of a group of explorers who mak...   2014-11-05
# 14  While the Civil War rages on between the Union...   1966-12-23
# 15  A man with a low IQ has accomplished great thi...   1994-06-23
# 16  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 17  A samurai answers a village's request for prot...   1954-04-26
# 18  In the final months of World War II, 14-year-o...   1988-04-16
# 19  A touching story of an Italian book seller of ...   1997-12-20
#
#     popularity  vote_average  vote_count
# 0      32.8997         8.715       29827
# 1      34.6298         8.700       22523
# 2      17.1064         8.571       13632
# 3      14.7781         8.566       17154
# 4      14.8697         8.556        9776
# 5      21.0908         8.534       18004
# 6      26.1735         8.527       35251
# 7       6.2220         8.518        4562
# 8      18.9930         8.505       18903
# 9      23.7994         8.494       26095
# 10     23.1796         8.493       20201
# 11     20.9811         8.486       29762
# 12     19.5159         8.500       12316
# 13     43.6428         8.468       38987
# 14     13.4305         8.468        9448
# 15     23.0911         8.462       29309
# 16     22.1178         8.452       14059
# 17      7.2436         8.451        4125
# 18      0.0091         8.444        6376
# 19      8.5971         8.440       13820

# %%
# Initialize an empty DataFrame outside the loop to store all results
temp_df = pd.DataFrame()

for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    
    temp_df = pd.concat([temp_df, df], ignore_index=True)

# %%
df()

# %%
df.shape

# %%
df.to_csv('movies.csv')
